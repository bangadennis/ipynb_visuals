# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
data=pd.read_csv('2015_KCSE_RESULTS.csv')

# %%
data[data.CENTRE_NAME=="KANGUI SECONDARY SCHOOL"]
# Out:
#        Index_number             CANDIDATE_NAME  MG  AGP    SBJ1    SBJ2  \
# 36492    7214102001       MAINA MBUGUA IBRAHIM  B+   72   101 B  102 B+
# 36493    7214102002   WARUKIRA WANG'ATI DENNIS  B+   71   101 B  102 A-
# 36494    7214102003         NGIGI KARIUKI MARK   B   66  101 B-   102 B
# 36495    7214102004     WANJIRU KANGETHE BILLY  B+   72  101 B+  102 A-
# 36496    7214102005             NJUGUNA JOSHUA   B   63  101 B-  102 B+
# 36497    7214102006       NJERI KAMAU ZACHARIA  B+   70  101 B-   102 B
# 36498    7214102007        MURAYA PAUL KARANJA  B+   69   101 B  102 B+
# 36499    7214102008      WANJIRU NJUGUNA DAVID   B   65   101 B  102 B-
# 36500    7214102009       GITAU JOSEPH MUIRURI  B-   53  101 C+   102 C
# 36501    7214102010       MUTAHI KINGORI SIMON  B-   58  101 B-  102 C+
# 36502    7214102011         MWANGI  PAUL MAINA  B-   55  101 C+   102 C
# 36503    7214102012      MWANGI PETER KING'ORI  B+   71   101 B  102 B+
# ...

# %%
girls.
# Out:
#   File "<ipython-input-120-13afc5f2bbb1>", line 1
#     girls.
#           ^
# SyntaxError: invalid syntax

# %%
data.AGP.se
# Out:
# Series([], Name: CENTRE_NAME, dtype: object)

# %%
data
# Out:
# Index_number        525724
# CANDIDATE'S NAME    525724
# MG                  525724
# AGP                 525724
# SBJ1                525724
# SBJ2                525539
# SBJ3                525455
# SBJ4                525428
# SBJ5                525419
# SBJ6                525415
# SBJ7                525413
# SBJ8                424225
# SBJ9                  1490
# CENTRE NAME         525724
# dtype: int64
