# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
data=pd.read_json('test002m-loc.json')
data=data.T

# %%
data.head()
# Out:
#                      accuracy    activity activity_confidence altitude  \
# -KBLmWfF10bXElIqGnqU      5.2         NaN                   0      140
# -KBLmYoLb3A_udaKTlbI      3.6  In Vehicle                  64      167
# -KBLm_3oaYfW3FUqsE4v      3.9  In Vehicle                  64      203
# -KBLmaEcbvZRU0mL1qab      3.9  In Vehicle                  64      157
# -KBLmbTZguCrFWptJ-zc      3.9  In Vehicle                  92      141
#
#                      battery_level bearing distance_change  \
# -KBLmWfF10bXElIqGnqU            44     140        30.70869
# -KBLmYoLb3A_udaKTlbI            44     167        17.07303
# -KBLm_3oaYfW3FUqsE4v            44     203        33.00179
# -KBLmaEcbvZRU0mL1qab            44     157        27.80296
# -KBLmbTZguCrFWptJ-zc            44     141        21.50421
#
#                                  lastupdate  latitude longitude     speed  \
# -KBLmWfF10bXElIqGnqU  25-02-2016 07:57:37:1 -1.276803  36.81166         0
# ...

# %%
data2=pd.read_json('test002m-acc.json')
data2=data2.T

# %%
data2.describe()
# Out:
#         acc_X  acc_Y  acc_Z               datetime      timestamp vehicleID
# count   21932  21932  21932                  21932          21932     21932
# unique  12194  12718  11638                  11864          21886         1
# top         0      0      0  25-02-2016 19:35:14:2  1456414636488  test002m
# freq     9730   9204  10290                     11              2     21932

# %%
data17=pd.read_json('test00170-loc.json')
data17=data17.T

# %%
data17.distance_change.sum()
# Out:
# 3589.3329639434814

# %%
timed=data17.timestamp.max()-data17.timestamp.min()

# %%
data17.min()
# Out:
# accuracy                                 3.8
# activity                          In Vehicle
# activity_confidence                       44
# altitude                                  20
# battery_level                             51
# bearing                                   20
# distance_change                      5.31406
# lastupdate             12-02-2016 12:48:00:8
# latitude                           -1.056153
# longitude                           37.08595
# speed                                      0
# timestamp                      1455270480833
# vehicleId                          test00170
# dtype: object

# %%
data17.speed.mean()
# Out:
# 21.609068392452432

# %%
data19=pd.read_json('test019-loc.json')
data19=data19.T

# %%
data19.head(157)
# Out:
#                      accuracy    activity activity_confidence altitude  \
# -KAz--uP3k5y4gNSZ-zV      7.6         NaN                   0        0
# -KAz-1coFc1RQOki6Zq7      4.2  In Vehicle                  72      250
# -KAz-2VTsGGeDJmvps2m      3.5  In Vehicle                  72      262
# -KAz-3pHQ8KvFa4c5p90      3.9  In Vehicle                 100      215
# -KAz-52jS-9zmVLIh09P      3.9  In Vehicle                 100      216
# -KAz-6HqjSLauL0AFMjk      3.9  In Vehicle                 100      251
# -KAz-7WUw1k_bc5raKH-      3.9  In Vehicle                  54      282
# -KAz-8hlcIe9P4mXCOHH      4.1  In Vehicle                  54      281
# -KAz-9wgVUrOTDAHHX_6      4.4  In Vehicle                  54      285
# -KAz-B9LlYF1JX6OORVd      4.6  In Vehicle                 100      280
# -KAz-CNM2cE9DTN_J2mz      4.3  In Vehicle                 100      276
# -KAz-DaqGr8Qo6HoE-Ak      4.2  In Vehicle                 100      280
# ...

# %%
data19=data19.head(157)

# %%
data19.distance_change.sum()
# Out:
# 6804.773476600647

# %%
fig, ax=plt.subplots(figsize=(12,8))

ax.plot(data19.timestamp, data19.distance_change)

# %%
test002=pd.read_json('test002-loc.json')
test002=test002.T

# %%
test002.distance_change.sum()
# Out:
# 50093.06234693527

# %%
test002.head(2221)
# Out:
#                      accuracy    activity activity_confidence altitude  \
# -K7Wubgbr5pT18vZ5V7C       12         NaN                 NaN   1650.4
# -K7WucPDLASYbyXsxHav     11.2         NaN                 NaN   1653.5
# -K7Wud8y7NotV5cEP1uv     10.6         NaN                 NaN   1654.8
# -K7Wudsnev8KVa7L494u     10.9         NaN                 NaN   1660.2
# -K7Wuebim2uxBLZia3p3     11.2         NaN                 NaN   1662.4
# -K7WufKz7dzeooUOJbiI     11.4         NaN                 NaN   1662.7
# -K7Wug5pO-L7jidJuxTp     11.5         NaN                 NaN   1663.2
# -K7WugoPYDmP0oPRfDAp     11.8         NaN                 NaN   1663.8
# -K7WuhXx4qavM07pTylN     12.1         NaN                 NaN   1663.8
# -K7WuiGkftRNAChfRwpP     12.1         NaN                 NaN     1664
# -K7Wuj-qhnXOwwIsVKy9     11.9         NaN                 NaN   1663.9
# -K7WujjJs0vx_xyg5jXg     12.3         NaN                 NaN   1663.7
# ...

# %%
test002macc=pd.read_json('test002m-acc.json')
test002macc=test002macc.T
test002macc=test002macc.head(1000)

# %%
fig, ax=plt.subplots(figsize=(16,8))

ax.plot(test002macc.timestamp, test002macc.acc_)

# %%
test002.head()
# Out:
#                      accuracy activity activity_confidence altitude  \
# -K7Wubgbr5pT18vZ5V7C       12      NaN                 NaN   1650.4
# -K7WucPDLASYbyXsxHav     11.2      NaN                 NaN   1653.5
# -K7Wud8y7NotV5cEP1uv     10.6      NaN                 NaN   1654.8
# -K7Wudsnev8KVa7L494u     10.9      NaN                 NaN   1660.2
# -K7Wuebim2uxBLZia3p3     11.2      NaN                 NaN   1662.4
#
#                      battery_level bearing distance_change  \
# -K7Wubgbr5pT18vZ5V7C            62       0             NaN
# -K7WucPDLASYbyXsxHav            62     295             NaN
# -K7Wud8y7NotV5cEP1uv            62     304             NaN
# -K7Wudsnev8KVa7L494u            62     304             NaN
# -K7Wuebim2uxBLZia3p3            62     299             NaN
#
#                                  lastupdate  latitude longitude longtitude  \
# -K7Wubgbr5pT18vZ5V7C  08-01-2016 18:46:01:0 -1.280297       NaN   36.82635
# ...

# %%
test002.to_csv('test002-loc.csv')

# %%
ls
# Out:
# collect/                 safedrive2.png      test002m-acceleration.csv
# data/                    safedrive3.png      test002m-acceleration.csv~
# demo.thedevelovers.com/  safedrive4.png      test002m-acc.json
# Distance test.ipynb      safedrive5.png      test002m-location.csv
# drivingspeeds.png        safedrive.json      test002m-loc.json
# flicksbootstrap.com/     safe-drive.png      test019-loc.json
# learn/                   safedrive.png       themes.3rdwavemedia.com/
# Presentation/            test00170-loc.json  Untitled0.ipynb
# safe.bmml                test002-loc.csv
# safedrive1.png           test002-loc.json

# %%
less=test002.longitude.isnull()

# %%
test002.longitude[less]=test002.longtitude[less]

# %%
test002.head()
# Out:
#                      accuracy activity activity_confidence altitude  \
# -K7Wubgbr5pT18vZ5V7C       12      NaN                 NaN   1650.4
# -K7WucPDLASYbyXsxHav     11.2      NaN                 NaN   1653.5
# -K7Wud8y7NotV5cEP1uv     10.6      NaN                 NaN   1654.8
# -K7Wudsnev8KVa7L494u     10.9      NaN                 NaN   1660.2
# -K7Wuebim2uxBLZia3p3     11.2      NaN                 NaN   1662.4
#
#                      battery_level bearing distance_change  \
# -K7Wubgbr5pT18vZ5V7C            62       0             NaN
# -K7WucPDLASYbyXsxHav            62     295             NaN
# -K7Wud8y7NotV5cEP1uv            62     304             NaN
# -K7Wudsnev8KVa7L494u            62     304             NaN
# -K7Wuebim2uxBLZia3p3            62     299             NaN
#
#                                  lastupdate  latitude longitude longtitude  \
# -K7Wubgbr5pT18vZ5V7C  08-01-2016 18:46:01:0 -1.280297  36.82635   36.82635
# ...

# %%
test002.to_csv('test002-location.csv')

# %%
data17.head()
# Out:
#                      accuracy    activity activity_confidence altitude  \
# -KAJsK-8e0oi8e5wKa3u      4.4  In Vehicle                  54      135
# -KAJsLDgwvU2ap_Rf-vn      3.9       Still                 100      129
# -KAJsMJfxjcHTRLb9wSb      3.8       Still                 100      122
# -KAJsNAwwS17RxnhbTg_        4       Still                 100      119
# -KAJsOOftltJDXJfaKJ6        4       Still                 100      100
#
#                      battery_level bearing distance_change  \
# -KAJsK-8e0oi8e5wKa3u            55     135        53.03961
# -KAJsLDgwvU2ap_Rf-vn            55     129        78.84613
# -KAJsMJfxjcHTRLb9wSb            55     122        70.18059
# -KAJsNAwwS17RxnhbTg_            55     119          45.651
# -KAJsOOftltJDXJfaKJ6            55     100        61.75404
#
#                                  lastupdate  latitude longitude     speed  \
# -KAJsK-8e0oi8e5wKa3u  12-02-2016 12:48:00:8 -1.054362  37.08595  29.84442
# ...

# %%
data17.to_csv('test-017-loc.csv')

# %%
data19.to_csv('test-019-loc.csv')

# %%
location=pd.read_json('location.json')

# %%
location.head()
# Out:
#                       Dan   ad  adm admi admin banga felix kbr302r kenya  \
# -K7OsVnywuNEt4HCczqI  NaN  NaN  NaN  NaN   NaN   NaN   NaN     NaN   NaN
# -K7OsWXxLP7K5XkFTLIh  NaN  NaN  NaN  NaN   NaN   NaN   NaN     NaN   NaN
# -K7OsXGeZdlCz6pt0QY3  NaN  NaN  NaN  NaN   NaN   NaN   NaN     NaN   NaN
# -K7OsY-y6ZwTiCfD5mOP  NaN  NaN  NaN  NaN   NaN   NaN   NaN     NaN   NaN
# -K7OsYjOqNajh5Glp5uS  NaN  NaN  NaN  NaN   NaN   NaN   NaN     NaN   NaN
#
#                      kinyori ...  test012 test013 test019 test0191 test020  \
# -K7OsVnywuNEt4HCczqI     NaN ...      NaN     NaN     NaN      NaN     NaN
# -K7OsWXxLP7K5XkFTLIh     NaN ...      NaN     NaN     NaN      NaN     NaN
# -K7OsXGeZdlCz6pt0QY3     NaN ...      NaN     NaN     NaN      NaN     NaN
# -K7OsY-y6ZwTiCfD5mOP     NaN ...      NaN     NaN     NaN      NaN     NaN
# -K7OsYjOqNajh5Glp5uS     NaN ...      NaN     NaN     NaN      NaN     NaN
#
#                      test08022016 testpje update   vc walk
# ...

# %%
location=location.T

# %%
location.test0016
# Out:
# -K7OsVnywuNEt4HCczqI    NaN
# -K7OsWXxLP7K5XkFTLIh    NaN
# -K7OsXGeZdlCz6pt0QY3    NaN
# -K7OsY-y6ZwTiCfD5mOP    NaN
# -K7OsYjOqNajh5Glp5uS    NaN
# -K7OsZTF4Lc6HWv8L3QY    NaN
# -K7Os_CTqDdDJzEPMQRU    NaN
# -K7Os_vr5v46pBAVpFCa    NaN
# -K7Osaf-GYhG5xlX5CHz    NaN
# -K7OsbOla099vCn1X44n    NaN
# -K7Osc7lELvw3iRUyNop    NaN
# -K7Oscra6ZiBY6xva0Rl    NaN
# -K7OsdacAxGFStW1iRen    NaN
# -K7OseKN8-eBifEE9WWj    NaN
# -K7Osf31v40OHSnpK5uC    NaN
# -K7OsfmnDtzG4sPRz4_p    NaN
# -K7OsgWe5gFTjpATvib-    NaN
# -K7OshFlJk6lc3PAAVdU    NaN
# -K7OshzgqIAp61xvVqcK    NaN
# -K7Osii6xNBr0fh4iIKp    NaN
# -K7OsjS_ctJ6VBPwVtkb    NaN
# -K7OskBHRWvZPpkLknDj    NaN
# -K7OskukPQEqjzrR9uWk    NaN
# -K7Osled6QEaf-kPwn-S    NaN
# -K7OsmNsZUDKu7b64wyv    NaN
# -K7Osn6ipai8IEOr5TCP    NaN
# -K7OsnqRLy1asnOtXRc9    NaN
# -K7Oso_YiyyXXi9G3vDV    NaN
# -K7OspJGkQgC8b0hJYAa    NaN
# -K7Osq2O46oeUn9ybo6n    NaN
#                        ...
# -KBOIXWoaOeEHb3Cs-Vv    NaN
# -KBOIYjhRs5r5CGMCFqF    NaN
# ...
